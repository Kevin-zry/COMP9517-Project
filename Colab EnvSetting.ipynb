jajxMUlgZfSJty8HaaPqlnmC5SAWjvchbDLHbEmFF2ukjmuMjGWZzEXfIuuaxnmDdsJdIYeA_bCVL5FvmaHfF9b-YFL04vf50e9UtPdGhcngF-Qm1RfRXrmwvnv9rBGcKO_Kw37pPo_lGB9hH2j4BurzZBam-8myPpKfQ=w397-h268-no?authuser=0" width = "300" height = "200" alt="图片名称"
# align=center>
# <br/>
# <br/>
# *   这时就可以调用drive里的文件里
# *   地址示例："/content/drive/Colab/data/DIC-C2DH-HeLa-train/01/t000.tif"
# *   其中文件夹"/content/drive/Colab/"便相当于drive里的Colab文件夹

# %% [markdown]
# # **测试一下是否可用GPU**
#
# *   colab中可提供的CPU，GPU列表

# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "0" 
import tensorflow as tf
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 313277786769281380
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 7368979369816699717
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 15591987794193203373
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11150726272
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 11729054183095031216
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %% [markdown]
# *   在上方工具栏中选择"Edit"-"Notebook setting"
# *   选择GPU
# <img src="https://lh3.googleusercontent.com/jhqXtRRL2NMxftFvD6oPS-yvag12byrA8lgJGaMMu7F-WnifvnuJ2LNsqM7vaXB6UroUu00QtqzyMnX8lfTL4VkkqtOAiJIuUmHbukykqGULGqc1x7giuJ58iSbx041_3X5U21iVobEtzt7JqqsgmOrpIOe9QtgZVAjxNjTTsjUIJKCVvumFRI9Ol8u7tXd4_vyn59w_buduRucjzgeRrJpUN-Ex29sVfpy2Z1RckMixTsQE6mfXNSIBd_7XNgrhNBQ1On2x9Bk8IcWZiwo7EM6v3vz6DCnCw4OpOlh1bw8_QQ69mZRkMqx6qboWHcU79iPdoC0GW6tY3OX5QW6Uf3UDbNnonW-0ucu1pksbMgLbqUe_p5a0C75fhYHBsPS5WqbEO6_XpLtfbXfGdD3irIrwiFFXxjkfS8fQ7OhBtVUgJYUervsnUEfTdZMbQRKUKuoK13CNmZXK4br-ikRrnzC79AlkRoZbYSg7C4CLFqMJSpAJ893ntHT7GLwY5nvdCpClA19iN1Pij4QJo1zt89z4JpdxmDyA1oc4Q1EYLLDCsWN25D_4L4_FF5S35R-cDCatnzQITG4_TNO2P9jmyFmFozVvHAuooek_FGUMjKne13DajSD7TJ1yoGxR8GqtIZTnjxKZ0b8lw3o6dwndsRqtjyDtOtQ7OjNQscjo2V725WJ2DyCN1U-32g=w469-h338-no?authuser=0" width = "300" height = "200" alt="图片名称"
# align=center>
# <br/>
# <br/>
#
# *   检查GPU是否已经可用

# %%
tf.config.list_physical_devices('GPU')
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-8-008cef80d2cd>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %% [markdown]
# # **Colab中的模块**
#
#
# *   colab里已经安装的模块
# *   如果需要除此以外的，则用 "!pip install name" 安装

# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ---------------
# absl-py                  0.9.0
# alabaster                0.7.12
# albumentations           0.1.12
# altair                   4.1.0
# asgiref                  3.2.10
# astor                    0.8.1
# astropy                  4.0.1.post1
# astunparse               1.6.3
# atari-py                 0.2.6
# atomicwrites             1.4.0
# attrs                    19.3.0
# audioread                2.1.8
# autograd                 1.3
# Babel                    2.8.0
# backcall                 0.2.0
# beautifulsoup4           4.6.3
# bleach                   3.1.5
# blis                     0.4.1
# bokeh                    2.1.1
# boto                     2.49.0
# boto3                    1.14.24
# botocore                 1.17.24
# Bottleneck               1.3.2
# branca                   0.4.1
# bs4                      0.0.1
# CacheControl             0.12.6
# cachetools               4.1.1
# ...
